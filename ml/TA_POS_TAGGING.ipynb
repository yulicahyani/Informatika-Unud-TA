# %% [markdown]
# # POS TAGGING BAHASA INDONESIA

# %%
from pprint import pprint
from nltk.tag import hmm
import dill
from nltk.tag.hmm  import HiddenMarkovModelTagger, HiddenMarkovModelTrainer
from nltk.probability import LidstoneProbDist
from nltk.tokenize import WordPunctTokenizer
import string

# %%
fname = "Indonesian_Manually_Tagged_Corpus.tsv"
fopen = open(fname,'r')
fdata = fopen.readlines()

# %%
sentences = []
sentence = []
for word in fdata:
    dt = word.replace('\n','').split('\t')
    if(len(dt) == 1):
        sentences.append(sentence)
        sentence = []
    else:
        sentence.append((dt[0],dt[1]))

# %%
print('All Sentences : %d ' % (len(sentences)))
cutoff = int(.8 * len(sentences))
training_sentences = sentences[:cutoff]
test_sentences = sentences[cutoff:]
print('Training Sentences : %d ' % (len(training_sentences)))
print('Testing Sentences : %d ' % (len(test_sentences)))
# Out:
# All Sentences : 10029
# Training Sentences : 8023
# Testing Sentences : 2006

# %%
print('Training Start')
trainer = HiddenMarkovModelTrainer()
tagger = trainer.train_supervised(training_sentences, estimator=lambda fd, bins: LidstoneProbDist(fd, 0.1, bins))
print('Training Completed')
# Out:
# Training Start
# Training Completed

# %%
print('Testing Start')
tagger.test(test_sentences, verbose=True)
print('Testing Completed')
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Entropy: 9.99519217699052
#
# ------------------------------------------------------------
# Test: Satu/CD orang/NN tewas/VB dan/CC belasan/CD lain/JJ -nya/PRP luka-luka/NN ketika/SC para/DT petani/NN coca/FW terlibat/VB bentrok/VB dengan/SC sejumlah/CD pemuda/NN dari/IN kalangan/NN menengah/JJ saat/NN unjuk rasa/NN soal/NN rencana/NN otonomi/NN regional/JJ oleh/IN gubernur/NN setempat/NN ./Z
#
# Untagged: Satu orang tewas dan belasan lain -nya luka-luka ketika para petani coca terlibat bentrok dengan sejumlah pemuda dari kalangan menengah saat unjuk rasa soal rencana otonomi regional oleh gubernur setempat .
#
# HMM-tagged: Satu/CD orang/NN tewas/VB dan/CC belasan/RB lain/JJ -nya/PRP luka-luka/NN ketika/SC para/DT petani/NN coca/SC terlibat/VB bentrok/VB dengan/IN sejumlah/CD pemuda/CD dari/IN kalangan/NN menengah/JJ saat/NN unjuk rasa/NN soal/NN rencana/NN otonomi/NN regional/JJ oleh/IN gubernur/NN setempat/NN ./Z
#
# Entropy: 22.964418348203857
#
# ------------------------------------------------------------
# Test: Dua/CD kelompok/NN pengunjuk rasa/NN tersebut/PR saling/RB baku hantam/NN dengan/IN kayu/NN dan/CC batu/NN ,/Z sementara/SC polisi/NN mencoba/VB memisahkan/VB dengan/SC gas air/NN ./Z
#
# Untagged: Dua kelompok pengunjuk rasa tersebut saling baku hantam dengan kayu dan batu , sementara polisi mencoba memisahkan dengan gas air .
#
# HMM-tagged: Dua/CD kelompok/NN pengunjuk rasa/NN tersebut/PR saling/RB baku hantam/JJ dengan/IN kayu/NN dan/CC batu/NN ,/Z sementara/SC polisi/NN mencoba/VB memisahkan/PRP dengan/IN gas air/NNP ./Z
#
# Entropy: 17.254660355006635
#
# ------------------------------------------------------------
# Test: Para/DT petani/NN coca/FW ,/Z yang/SC mendukung/VB presiden/NNP Evo/NNP Morales/NNP dan/CC program/NN refomasi/NN -nya/PRP ,/Z menuntut/VB pengunduran diri/NN gubernur/NNP kawasan/NN Cochabamba/NNP Manred/NNP Reyes/NNP karena/SC mengusulkan/VB suatu/CD referendum/NN mengenai/IN pemerintahan/NN otonomi/NN ./Z
#
# Untagged: Para petani coca , yang mendukung presiden Evo Morales dan program refomasi -nya , menuntut pengunduran diri gubernur kawasan Cochabamba Manred Reyes karena mengusulkan suatu referendum mengenai pemerintahan otonomi .
#
# HMM-tagged: Para/DT petani/NN coca/PR ,/Z yang/SC mendukung/VB presiden/NN Evo/PR Morales/Z dan/CC program/NN refomasi/JJ -nya/PRP ,/Z menuntut/VB pengunduran diri/NN gubernur/NN kawasan/NN Cochabamba/FW Manred/FW Reyes/FW karena/SC mengusulkan/VB suatu/CD referendum/NN mengenai/IN pemerintahan/NN otonomi/NN ./Z
#
# Entropy: 31.035148089188553
#
# ------------------------------------------------------------
# Test: Sementara/SC itu/PR para/DT pemuda/NN yang/SC sebagian besar/NN dari/IN kalangan/NN kelas menengah/NN juga/RB mengadakan/VB unjuk rasa/NN tandingan/NN ,/Z mendukung/VB rencana/NN gubernur/NN dan/CC menentang/VB kebijakan/NN sosialis/NN Morales/NNP ./Z
#
# Untagged: Sementara itu para pemuda yang sebagian besar dari kalangan kelas menengah juga mengadakan unjuk rasa tandingan , mendukung rencana gubernur dan menentang kebijakan sosialis Morales .
#
# HMM-tagged: Sementara/SC itu/PR para/DT pemuda/NN yang/SC sebagian besar/NN dari/IN kalangan/NN kelas menengah/NN juga/RB mengadakan/VB unjuk rasa/NN tandingan/NN ,/Z mendukung/VB rencana/NN gubernur/NN dan/CC menentang/VB kebijakan/NN sosialis/NN Morales/PR ./Z
#
# Entropy: 19.433334331096233
#
# ------------------------------------------------------------
# Test: Kota/NN berpenduduk/VB 500/CD ribu/CD jiwa/NN itu/PR lumpuh/JJ sejak/IN Senin/NNP karena/SC unjuk rasa/NN para/DT petani/NN yang/SC memblok/VB seluruh/CD jalan masuk/NN ./Z
#
# Untagged: Kota berpenduduk 500 ribu jiwa itu lumpuh sejak Senin karena unjuk rasa para petani yang memblok seluruh jalan masuk .
#
# HMM-tagged: Kota/NNP berpenduduk/VB 500/CD ribu/CD jiwa/NN itu/PR lumpuh/JJ sejak/IN Senin/NNP karena/SC unjuk rasa/NN para/DT petani/NN yang/SC memblok/VB seluruh/CD jalan masuk/NN ./Z
#
# Entropy: 16.381602752296928
#
# ------------------------------------------------------------
# Test: Hari/NN Senin/NNP lalu/CC juga/RB terjadi/VB bentrok/VB antara/IN ribuan/CD petani/NN coca/FW dengan/IN polisi/NN ,/Z mengakibatkan/VB 31/CD orang/NN cedera/JJ ,/Z termasuk/VB 10/CD wartawan/NN di/IN kota/NN yang/SC terletak/VB 400/CD km/NND tenggara/NN ibu kota/NN La/NNP Paz/NNP itu/PR ./Z
#
# Untagged: Hari Senin lalu juga terjadi bentrok antara ribuan petani coca dengan polisi , mengakibatkan 31 orang cedera , termasuk 10 wartawan di kota yang terletak 400 km tenggara ibu kota La Paz itu .
#
# HMM-tagged: Hari/NNP Senin/NNP lalu/CC juga/RB terjadi/VB bentrok/VB antara/IN ribuan/CD petani/NN coca/JJ dengan/IN polisi/NN ,/Z mengakibatkan/VB 31/CD orang/NN cedera/JJ ,/Z termasuk/VB 10/CD wartawan/NN di/IN kota/NN yang/SC terletak/VB 400/CD km/NND tenggara/NN ibu kota/NN La/FW Paz/FW itu/PR ./Z
#
# Entropy: 22.092633162460412
#
# ------------------------------------------------------------
# Test: Kesenjangan/NN antara/IN warga/NN miskin/JJ ,/Z sebagian besar/NN orang/NN asli/JJ di/IN dataran tinggi/NN ,/Z dan/CC warga/NN kaya/JJ di/IN dataran rendah/NN semakin/RB tajam/JJ di/IN Bolivia/NNP sejak/IN Morales/NNP (/Z 55/CD tahun/NN )/Z menjadi/VB presiden/NN tahun/NN lalu/CC dengan/SC agenda/NN sosialis/NN yang/SC ambisius/JJ ./Z
#
# Untagged: Kesenjangan antara warga miskin , sebagian besar orang asli di dataran tinggi , dan warga kaya di dataran rendah semakin tajam di Bolivia sejak Morales ( 55 tahun ) menjadi presiden tahun lalu dengan agenda sosialis yang ambisius .
#
# HMM-tagged: Kesenjangan/PRP antara/IN warga/NN miskin/JJ ,/Z sebagian besar/NN orang/NN asli/JJ di/IN dataran tinggi/NNP ,/Z dan/CC warga/NN kaya/JJ di/IN dataran rendah/NN semakin/RB tajam/JJ di/IN Bolivia/NNP sejak/IN Morales/NNP (/Z 55/CD tahun/NN )/Z menjadi/VB presiden/NN tahun/NN lalu/CC dengan/IN agenda/NN sosialis/NN yang/SC ambisius/PRP ./Z
#
# Entropy: 26.155608090562367
#
# ------------------------------------------------------------
# Test: Empat/CD provinsi/NN kaya/JJ ,/Z Santa/NNP Cruz/NNP ,/Z Beni/NNP ,/Z Pando/NNP dan/CC Tarija/NNP menuntut/VB otonomi/NN yang/SC lebih/RB luas/JJ ,/Z sebagai/IN respon/NN atas/IN rencana/NN Morales/NNP membagi-bagikan/VB kembali/VB kepemilikan/NN lahan/NN untuk/IN warga/NN miskin/JJ Bolivia/NNP ,/Z dan/CC menyusun/VB kembali/VB undang-undang/NN ./Z
#
# Untagged: Empat provinsi kaya , Santa Cruz , Beni , Pando dan Tarija menuntut otonomi yang lebih luas , sebagai respon atas rencana Morales membagi-bagikan kembali kepemilikan lahan untuk warga miskin Bolivia , dan menyusun kembali undang-undang .
#
# HMM-tagged: Empat/CD provinsi/NN kaya/JJ ,/Z Santa/NNP Cruz/NNP ,/Z Beni/NNP ,/Z Pando/NNP dan/CC Tarija/MD menuntut/VB otonomi/NN yang/SC lebih/RB luas/JJ ,/Z sebagai/IN respon/NN atas/IN rencana/NN Morales/PR membagi-bagikan/MD kembali/VB kepemilikan/NN lahan/NN untuk/SC warga/NN miskin/JJ Bolivia/NNP ,/Z dan/CC menyusun/VB kembali/VB undang-undang/NN ./Z
#
# Entropy: 38.780365464948446
#
# ------------------------------------------------------------
# Test: Para/DT pemimpin/NN di/IN Cochabamba/NNP baru-baru ini/RB bergabung/VB dengan/SC gerakan/NN menuntut/VB otonomi/NN ./Z
#
# Untagged: Para pemimpin di Cochabamba baru-baru ini bergabung dengan gerakan menuntut otonomi .
#
# HMM-tagged: Para/DT pemimpin/NN di/IN Cochabamba/NN baru-baru ini/RB bergabung/VB dengan/IN gerakan/NN menuntut/VB otonomi/NN ./Z
#
# Entropy: 9.343708541492948
#
# ------------------------------------------------------------
# Test: Sekretaris/NNP Jenderal/NNP Organisasi/NNP Konferensi/NNP Islam/NNP (/Z OKI/NNP )/Z Ekmeleddin/NNP Ihsanoglu/NNP menyatakan/VB keprihatinan/NN serius/JJ atas/IN meluas/VB -nya/PRP konflik/NN militer/NN di/IN Somalia/NNP ,/Z terutama/JJ serangan/NN udara/NN di/IN selatan/NN negara/NN ,/Z yang/SC dilaporkan/VB mengakibatkan/VB hilang/VB -nya/PRP nyawa/NN warga/NN tidak/NEG berdosa/VB dan/CC kerusakan/NN harta benda/NN ./Z
#
# Untagged: Sekretaris Jenderal Organisasi Konferensi Islam ( OKI ) Ekmeleddin Ihsanoglu menyatakan keprihatinan serius atas meluas -nya konflik militer di Somalia , terutama serangan udara di selatan negara , yang dilaporkan mengakibatkan hilang -nya nyawa warga tidak berdosa dan kerusakan harta benda .
#
# HMM-tagged: Sekretaris/NNP Jenderal/NNP Organisasi/NNP Konferensi/NNP Islam/NNP (/Z OKI/NNP )/Z Ekmeleddin/SC Ihsanoglu/MD menyatakan/VB keprihatinan/NN serius/JJ atas/IN meluas/VB -nya/PRP konflik/NN militer/NN di/IN Somalia/NNP ,/Z terutama/JJ serangan/NN udara/NN di/IN selatan/NN negara/NN ,/Z yang/SC dilaporkan/VB mengakibatkan/VB hilang/VB -nya/PRP nyawa/NN warga/NN tidak/NEG berdosa/JJ dan/CC kerusakan/NN harta benda/PR ./Z
#
# Entropy: 27.37434867114834
#
# ------------------------------------------------------------
# Test: Dia/PRP juga/RB mengumumkan/VB rencana/NN untuk/SC mengirimkan/VB misi/NN tingkat/NN tinggi/JJ OKI/NNP secepat/JJ -nya/PRP ke/IN Somalia/NNP dan/CC negara/NN tetangga/NN -nya/PRP sebagai/IN bagian/NN dari/IN misi/NN perdamaian/NN ./Z
#
# Untagged: Dia juga mengumumkan rencana untuk mengirimkan misi tingkat tinggi OKI secepat -nya ke Somalia dan negara tetangga -nya sebagai bagian dari misi perdamaian .
#
# HMM-tagged: Dia/PRP juga/RB mengumumkan/VB rencana/NN untuk/SC mengirimkan/VB misi/NN tingkat/NN tinggi/JJ OKI/RB secepat/JJ -nya/PRP ke/IN Somalia/NNP dan/CC negara/NN tetangga/NN -nya/PRP sebagai/IN bagian/NN dari/IN misi/NN perdamaian/NN ./Z
#
# Entropy: 8.571571613143716
#
# ------------------------------------------------------------
# Test: Dalam/IN sebuah/NND pernyataan/NN pers/NN ,/Z pemimpin/NN OKI/NNP memperingatkan/VB bahwa/SC Aksi/NN militer/NN tidak/NEG perlu/MD itu/PR dapat/MD merusak/VB kemajuan/NN yang/SC dicapai/VB dalam/IN upaya/NN menciptakan/VB perdamaian/NN jangka panjang/NN ,/Z stabilitas/NN dan/CC rekonsiliasi/NN di/IN negara/NN itu/PR serta/CC memiliki/VB potensi/NN untuk/SC mengganggu/VB seluruh/CD kawasan/NN dan/CC bahkan/RB di/IN luar/NN itu/PR ./Z
#
# Untagged: Dalam sebuah pernyataan pers , pemimpin OKI memperingatkan bahwa Aksi militer tidak perlu itu dapat merusak kemajuan yang dicapai dalam upaya menciptakan perdamaian jangka panjang , stabilitas dan rekonsiliasi di negara itu serta memiliki potensi untuk mengganggu seluruh kawasan dan bahkan di luar itu .
#
# HMM-tagged: Dalam/IN sebuah/NND pernyataan/NN pers/NN ,/Z pemimpin/NN OKI/NNP memperingatkan/VB bahwa/SC Aksi/NN militer/NN tidak/NEG perlu/MD itu/PR dapat/MD merusak/VB kemajuan/NN yang/SC dicapai/VB dalam/IN upaya/NN menciptakan/VB perdamaian/NN jangka panjang/NN ,/Z stabilitas/NN dan/CC rekonsiliasi/NN di/IN negara/NN itu/PR serta/CC memiliki/VB potensi/NN untuk/SC mengganggu/VB seluruh/CD kawasan/NN dan/CC bahkan/RB di/IN luar/NN itu/PR ./Z
#
# Entropy: 13.375299899218954
#
# ------------------------------------------------------------
# Test: Ihsanoglu/NNP menyeru/VB seluruh/CD warga/NN Somalia/NNP ,/Z terutama/JJ pemimpin/NN dari/IN faksi-faksi/NN yang/SC berbeda/VB untuk/IN bekerja/VB bagi/IN stabilitas/NN negara/NN mereka/PRP serta/CC meredakan/VB pertikaian/NN menuju/VB suatu/CD rekonsiliasi/NN nasional/JJ ./Z
#
# Untagged: Ihsanoglu menyeru seluruh warga Somalia , terutama pemimpin dari faksi-faksi yang berbeda untuk bekerja bagi stabilitas negara mereka serta meredakan pertikaian menuju suatu rekonsiliasi nasional .
#
# HMM-tagged: Ihsanoglu/SC menyeru/VB seluruh/CD warga/NN Somalia/NNP ,/Z terutama/JJ pemimpin/NN dari/IN faksi-faksi/NN yang/SC berbeda/VB untuk/SC bekerja/VB bagi/IN stabilitas/NN negara/NN mereka/PRP serta/CC meredakan/VB pertikaian/PRP menuju/VB suatu/CD rekonsiliasi/NN nasional/JJ ./Z
#
# Entropy: 17.870833856388394
#
# ------------------------------------------------------------
# Test: Dia/PRP juga/RB menyeru/VB seluruh/CD negara/NN tetangga/NN dan/CC kekuatan/NN dunia/NN untuk/SC segera/RB mengakhiri/VB campur tangan/NN militer/NN mereka/PRP di/IN negara/NN itu/PR ./Z
#
# Untagged: Dia juga menyeru seluruh negara tetangga dan kekuatan dunia untuk segera mengakhiri campur tangan militer mereka di negara itu .
#
# HMM-tagged: Dia/PRP juga/RB menyeru/VB seluruh/CD negara/NN tetangga/NN dan/CC kekuatan/NN dunia/NN untuk/SC segera/RB mengakhiri/VB campur tangan/NN militer/NN mereka/PRP di/IN negara/NN itu/PR ./Z
#
# Entropy: 4.539139673294926
#
# ------------------------------------------------------------
# Test: Sekretaris/NNP Jenderal/NNP OKI/NNP mendesak/VB Perserikatan/NNP Bangsa-Bangsa/NNP (/Z PBB/NNP )/Z dan/CC masyarakat/NN internasional/JJ untuk/SC memainkan peran/VB yang/SC efektif/JJ guna/SC menghentikan/VB situasi/NN penuh/JJ kekerasan/NN di/IN Somalia/NNP ./Z
#
# Untagged: Sekretaris Jenderal OKI mendesak Perserikatan Bangsa-Bangsa ( PBB ) dan masyarakat internasional untuk memainkan peran yang efektif guna menghentikan situasi penuh kekerasan di Somalia .
#
# HMM-tagged: Sekretaris/NNP Jenderal/NNP OKI/NNP mendesak/VB Perserikatan/NNP Bangsa-Bangsa/NNP (/Z PBB/NNP )/Z dan/CC masyarakat/NN internasional/JJ untuk/SC memainkan peran/VB yang/SC efektif/JJ guna/SC menghentikan/VB situasi/NN penuh/JJ kekerasan/NN di/IN Somalia/NNP ./Z
#
# Entropy: 8.028291953011804
#
# ------------------------------------------------------------
# Test: Sekretaris/NNP Jenderal/NNP terus/RB mengikuti/VB perkembangan/NN di/IN Somalia/NNP dan/CC bekerja/VB dengan/IN masyarakat/NN internasional/JJ untuk/SC mewujudkan/VB perdamaian/NN ,/Z mengembalikan/VB keadaan/NN normal/JJ dan/CC rekonsiliasi/NN nasional/JJ di/IN negara/NN itu/PR ,/Z kata/VB pernyataan/NN itu/PR ./Z
#
# Untagged: Sekretaris Jenderal terus mengikuti perkembangan di Somalia dan bekerja dengan masyarakat internasional untuk mewujudkan perdamaian , mengembalikan keadaan normal dan rekonsiliasi nasional di negara itu , kata pernyataan itu .
#
# HMM-tagged: Sekretaris/NNP Jenderal/NNP terus/RB mengikuti/VB perkembangan/NN di/IN Somalia/NNP dan/CC bekerja/VB dengan/IN masyarakat/NN internasional/JJ untuk/SC mewujudkan/VB perdamaian/NN ,/Z mengembalikan/VB keadaan/NN normal/JJ dan/CC rekonsiliasi/NN nasional/JJ di/IN negara/NN itu/PR ,/Z kata/VB pernyataan/NN itu/PR ./Z
#
# Entropy: 5.1991601755246935
#
# ------------------------------------------------------------
# Test: Seorang/NND hakim/NN Argentina/NNP ,/Z Kamis/NNP ,/Z mengeluarkan/VB sebuah/NND surat perintah/NN penahanan/NN bagi/IN mantan/NNP Presiden/NNP Maria/NNP Estela/NNP Martinez/NNP de/NNP Peron/NNP ,/Z pemimpin/NN yang/SC lebih/RB dikenal/VB sebagai/IN Isabel/NNP Peron/NNP ,/Z atas/IN kasus/NN hilang/VB -nya/PRP seorang/NND aktivis/NN pelajar/NN pada/IN 1970an/CD ./Z
#
# Untagged: Seorang hakim Argentina , Kamis , mengeluarkan sebuah surat perintah penahanan bagi mantan Presiden Maria Estela Martinez de Peron , pemimpin yang lebih dikenal sebagai Isabel Peron , atas kasus hilang -nya seorang aktivis pelajar pada 1970an .
#
# HMM-tagged: Seorang/NND hakim/NN Argentina/NNP ,/Z Kamis/NNP ,/Z mengeluarkan/VB sebuah/NND surat perintah/NN penahanan/NN bagi/IN mantan/NNP Presiden/NNP Maria/NNP Estela/NNP Martinez/NNP de/NNP Peron/NNP ,/Z pemimpin/NN yang/SC lebih/RB dikenal/VB sebagai/IN Isabel/SYM Peron/CD ,/Z atas/IN kasus/NN hilang/VB -nya/PRP seorang/NND aktivis/NN pelajar/NN pada/IN 1970an/CD ./Z
#
# Entropy: 34.45822498568899
#
# ------------------------------------------------------------
# Test: Hakim/NNP Hector/NNP Acosta/NNP mengeluarkan/VB surat perintah/NN terhadap/IN janda/NN tokoh/NN legendaris/JJ Argentina/NNP ,/Z mantan/NNP Presiden/NNP Juan/NNP Peron/NNP ,/Z di/IN San/NNP Rafael/NNP di/IN barat/NN Provinsi/NNP Mendoza/NNP ./Z
#
# Untagged: Hakim Hector Acosta mengeluarkan surat perintah terhadap janda tokoh legendaris Argentina , mantan Presiden Juan Peron , di San Rafael di barat Provinsi Mendoza .
#
# HMM-tagged: Hakim/NN Hector/PR Acosta/MD mengeluarkan/VB surat perintah/NN terhadap/IN janda/NN tokoh/NN legendaris/NNP Argentina/NNP ,/Z mantan/NNP Presiden/NNP Juan/NNP Peron/NNP ,/Z di/IN San/NNP Rafael/NNP di/IN barat/NNP Provinsi/NNP Mendoza/NNP ./Z
#
# Entropy: 33.9065067011124
#
# ------------------------------------------------------------
# Test: Dia/PRP mengatakan/VB bahwa/SC mantan/NNP Presiden/NNP Isabel/NNP Peron/NNP harus/MD ditangkap/VB terkait/VB atas/IN kasus/NN hilang/VB -nya/PRP Hector/NNP Aldo/NNP Fagetti/NNP Gallego/NNP pada/IN 1976/CD ./Z
#
# Untagged: Dia mengatakan bahwa mantan Presiden Isabel Peron harus ditangkap terkait atas kasus hilang -nya Hector Aldo Fagetti Gallego pada 1976 .
#
# HMM-tagged: Dia/PRP mengatakan/VB bahwa/SC mantan/JJ Presiden/NNP Isabel/Z Peron/SC harus/MD ditangkap/VB terkait/VB atas/IN kasus/NN hilang/VB -nya/PRP Hector/Z Aldo/FW Fagetti/FW Gallego/FW pada/IN 1976/CD ./Z
#
# Entropy: 26.288283845444038
#
# ------------------------------------------------------------
# Test: Hakim/NN mengatakan/VB bahwa/SC pria/NN itu/PR menghilang/VB setelah/SC Peron/NNP dituduh/VB menandatangani/VB sebuah/NND perintah/NN kepada/IN militer/NN -nya/PRP untuk/SC membersihkan/VB elemen/NN bawah/NN tanah negara/NN itu/PR ./Z
#
# Untagged: Hakim mengatakan bahwa pria itu menghilang setelah Peron dituduh menandatangani sebuah perintah kepada militer -nya untuk membersihkan elemen bawah tanah negara itu .
#
# HMM-tagged: Hakim/NN mengatakan/VB bahwa/SC pria/NN itu/PR menghilang/VB setelah/SC Peron/MD dituduh/VB menandatangani/VB sebuah/NND perintah/NN kepada/IN militer/NN -nya/PRP untuk/SC membersihkan/VB elemen/NN bawah/NN tanah negara/NN itu/PR ./Z
#
# Entropy: 17.290263801831237
#
# ------------------------------------------------------------
# Test: Peron/NNP ,/Z yang/SC saat/NN ini/PR tinggal/VB di/IN Madrid/NNP ,/Z menjadi/VB presiden/NN setelah/SC kematian/NN suami/NN -nya/PRP ./Z
#
# Untagged: Peron , yang saat ini tinggal di Madrid , menjadi presiden setelah kematian suami -nya .
#
# HMM-tagged: Peron/PRP ,/Z yang/SC saat/NN ini/PR tinggal/VB di/IN Madrid/NNP ,/Z menjadi/VB presiden/NN setelah/SC kematian/NN suami/NN -nya/PRP ./Z
#
# Entropy: 9.473747683281479
#
# ------------------------------------------------------------
# Test: Pemerintahan/NN dia/PRP digulingkan/VB sebuah/NND kudeta/NN pada/IN 1976/CD ./Z
#
# Untagged: Pemerintahan dia digulingkan sebuah kudeta pada 1976 .
#
# HMM-tagged: Pemerintahan/NN dia/PRP digulingkan/VB sebuah/NND kudeta/NN pada/IN 1976/CD ./Z
#
# Entropy: 6.0711180330087595
#
# ------------------------------------------------------------
# Test: Hakim/NN federal/JJ lain/JJ sedang/SC menyelidiki/VB keterlibatan/NN -nya/PRP dalam/IN Kelompok/NNP Anti/NNP -/NNP Komunis/NNP Argentina/NNP ,/Z sebuah/NND pasukan/NN kematian/NN sayap/NN kanan/NN yang/SC dikenal/VB sebagai/IN Triple/NNP A/NNP ./Z
#
# Untagged: Hakim federal lain sedang menyelidiki keterlibatan -nya dalam Kelompok Anti - Komunis Argentina , sebuah pasukan kematian sayap kanan yang dikenal sebagai Triple A .
#
# HMM-tagged: Hakim/NN federal/RB lain/JJ sedang/MD menyelidiki/VB keterlibatan/NN -nya/PRP dalam/IN Kelompok/NN Anti/NNP -/Z Komunis/NNP Argentina/NNP ,/Z sebuah/NND pasukan/NN kematian/NN sayap/NN kanan/NN yang/SC dikenal/VB sebagai/IN Triple/NNP A/NNP ./Z
#
# Entropy: 18.38471220549863
#
# ------------------------------------------------------------
# Test: Kelompok/NN itu/PR dibentuk/VB oleh/IN seorang/NND menteri/NN pemerintah/NN dalam/IN masa/NN pemerintahan/NN Peron/NNP ,/Z dan/CC dituduh/VB bertanggung jawab/VB atas/IN kematian/NN 1.500/CD orang/NN ./Z
#
# Untagged: Kelompok itu dibentuk oleh seorang menteri pemerintah dalam masa pemerintahan Peron , dan dituduh bertanggung jawab atas kematian 1.500 orang .
#
# HMM-tagged: Kelompok/NN itu/PR dibentuk/VB oleh/IN seorang/NND menteri/NN pemerintah/NN dalam/IN masa/NN pemerintahan/NN Peron/PR ,/Z dan/CC dituduh/VB bertanggung jawab/VB atas/IN kematian/NN 1.500/CD orang/NN ./Z
#
# Entropy: 11.859418538113612
#
# ------------------------------------------------------------
# Test: Sedikit/CD -nya/PRP tujuh/CD orang/NN termasuk/VB seorang/NND hakim/NN senior/JJ ,/Z Arif/NNP Bhinder/NNP ,/Z ditembak/VB mati/VB di/IN kota/NN Pakistan/NNP ,/Z Lahore/NNP ,/Z Jumat/NNP ,/Z dalam/IN peristiwa/NN yang/SC tampaknya/RB merupakan/VB serangan/NN dari/IN lawan/NN politik/NN di/IN Provinsi/NNP Punjab/NNP Tengah/NNP ,/Z menurut/IN laporan/NN media/NN ./Z
#
# Untagged: Sedikit -nya tujuh orang termasuk seorang hakim senior , Arif Bhinder , ditembak mati di kota Pakistan , Lahore , Jumat , dalam peristiwa yang tampaknya merupakan serangan dari lawan politik di Provinsi Punjab Tengah , menurut laporan media .
#
# HMM-tagged: Sedikit/SC -nya/PRP tujuh/CD orang/NN termasuk/VB seorang/NND hakim/NN senior/JJ ,/Z Arif/NNP Bhinder/NNP ,/Z ditembak/VB mati/VB di/IN kota/NN Pakistan/NNP ,/Z Lahore/NNP ,/Z Jumat/NNP ,/Z dalam/IN peristiwa/NN yang/SC tampaknya/RB merupakan/VB serangan/NN dari/IN lawan/NN politik/NN di/IN Provinsi/NNP Punjab/NNP Tengah/NNP ,/Z menurut/IN laporan/NN media/NN ./Z
#
# Entropy: 20.11033662819464
#
# ------------------------------------------------------------
# Test: Bhinder/NNP sedang/MD melakukan/VB perjalanan/NN dengan/SC kawalan/NN petugas/NN polisi/NN ketika/SC pria-pria/NN bersenjata/VB dengan/IN dua/CD buah/NND kendaraan/NN menghentikan/VB iring-iringan/NN di/IN ibu kota/NN Provinsi/NN ,/Z menurut/IN laporan/NN televisi/NN swasta/JJ Geo/NNP -/NNP TV/NNP ./Z
#
# Untagged: Bhinder sedang melakukan perjalanan dengan kawalan petugas polisi ketika pria-pria bersenjata dengan dua buah kendaraan menghentikan iring-iringan di ibu kota Provinsi , menurut laporan televisi swasta Geo - TV .
#
# HMM-tagged: Bhinder/PRP sedang/MD melakukan/VB perjalanan/NN dengan/IN kawalan/NN petugas/NN polisi/NN ketika/SC pria-pria/MD bersenjata/VB dengan/IN dua/CD buah/NND kendaraan/NN menghentikan/VB iring-iringan/PRP di/IN ibu kota/NN Provinsi/NNP ,/Z menurut/IN laporan/NN televisi/NN swasta/JJ Geo/NNP -/Z TV/NN ./Z
#
# Entropy: 24.845576943890443
#
# ------------------------------------------------------------
# Test: Serangan/NN di/IN jalanan/NN yang/SC sibuk/JJ di/IN pusat/NN kota/NN itu/PR mengakibatkan/VB sedikit/CD -nya/PRP tujuh/CD orang/NN meninggal/VB dan/CC lebih/RB dari/IN 10/CD orang/NN luka-luka/NN ,/Z kata/VB polisi/NN ./Z
#
# Untagged: Serangan di jalanan yang sibuk di pusat kota itu mengakibatkan sedikit -nya tujuh orang meninggal dan lebih dari 10 orang luka-luka , kata polisi .
#
# HMM-tagged: Serangan/NN di/IN jalanan/NN yang/SC sibuk/VB di/IN pusat/NN kota/NN itu/PR mengakibatkan/VB sedikit/CD -nya/PRP tujuh/CD orang/NN meninggal/VB dan/CC lebih/RB dari/IN 10/CD orang/NN luka-luka/NN ,/Z kata/VB polisi/NN ./Z
#
# Entropy: 12.915762285059806
#
# ------------------------------------------------------------
# Test: Salah seorang/CD penyerang/NN dan/CC tiga/CD orang/NND petugas/NN keamanan/NN juga/RB menjadi/VB korban/NN dalam/IN peristiwa/NN baku tembak/NN itu/PR ./Z
#
# Untagged: Salah seorang penyerang dan tiga orang petugas keamanan juga menjadi korban dalam peristiwa baku tembak itu .
#
# HMM-tagged: Salah seorang/CD penyerang/NN dan/CC tiga/CD orang/NN petugas/NN keamanan/NN juga/RB menjadi/VB korban/NN dalam/IN peristiwa/NN baku tembak/NN itu/PR ./Z
#
# Entropy: 6.3629441941093035
#
# ------------------------------------------------------------
# Test: Ketegangan/NN meningkat/VB ketika/SC ratusan/CD warga/NN lokal/JJ termasuk/VB kerabat/NN dari/IN korban/NN berkumpul/VB di/IN luar/NN rumah sakit/NN di mana/SC korban/NN luka-luka/NN dibawa/VB untuk/SC menjalani/VB perawatan/NN ./Z
#
# Untagged: Ketegangan meningkat ketika ratusan warga lokal termasuk kerabat dari korban berkumpul di luar rumah sakit di mana korban luka-luka dibawa untuk menjalani perawatan .
#
# HMM-tagged: Ketegangan/NN meningkat/VB ketika/SC ratusan/CD warga/NN lokal/JJ termasuk/VB kerabat/NN dari/IN korban/NN berkumpul/VB di/IN luar/NN rumah sakit/NN di mana/SC korban/NN luka-luka/NN dibawa/VB untuk/SC menjalani/VB perawatan/NN ./Z
#
# Entropy: 14.951836867936846
#
# ------------------------------------------------------------
# Test: Korban/NN meninggal/VB dapat/MD terus/RB bertambah/VB karena/SC empat/CD dari/IN korban/NN luka-luka/NN berada/VB dalam/IN kondisi/NN kritis/JJ ,/Z kata/VB Geo/NNP ./Z
#
# Untagged: Korban meninggal dapat terus bertambah karena empat dari korban luka-luka berada dalam kondisi kritis , kata Geo .
#
# HMM-tagged: Korban/NN meninggal/VB dapat/MD terus/RB bertambah/VB karena/SC empat/CD dari/IN korban/NN luka-luka/NN berada/VB dalam/IN kondisi/NN kritis/JJ ,/Z kata/VB Geo/NNP ./Z
#
# Entropy: 11.15751830304868
#
# ------------------------------------------------------------
# Test: Pemerintah/NNP komunis/NNP Vietnam/NNP berencana/VB menswastakan/VB lebih/RB dari/IN 100/CD badan/NN usaha/NN milik/NN pemerintah/NN ,/Z termasuk/VB industri/NN minyak/NN dan/CC gas/NN ,/Z kata/VB perdana menteri/NNP Nguyen/NNP Tan/NNP Dung/NNP ,/Z Jumat/NNP ./Z
#
# Untagged: Pemerintah komunis Vietnam berencana menswastakan lebih dari 100 badan usaha milik pemerintah , termasuk industri minyak dan gas , kata perdana menteri Nguyen Tan Dung , Jumat .
#
# HMM-tagged: Pemerintah/NN komunis/NN Vietnam/NNP berencana/VB menswastakan/PRP lebih/RB dari/IN 100/CD badan/NN usaha/NN milik/NN pemerintah/NN ,/Z termasuk/VB industri/NN minyak/NN dan/CC gas/NN ,/Z kata/VB perdana menteri/NN Nguyen/NNP Tan/NNP Dung/NNP ,/Z Jumat/NNP ./Z
#
# Entropy: 19.700252640696117
#
# ------------------------------------------------------------
# Test: Berbicara/VB di/IN sela/NN KTT/NNP ASEAN/NNP ,/Z Dung/NNP mengemukakan/VB kepada/IN Reuters/NNP ,/Z negara/NN -nya/PRP ,/Z yang/SC pada/IN Kamis/NNP ,/Z resmi/JJ menjadi/VB anggota/NN Organisasi/NNP Perdagangan/NNP Dunia/NNP (/Z WTO/NNP )/Z ,/Z akan/MD memperkuat/VB transparansi/NN untuk/SC menarik/VB investasi/NN asing/JJ ./Z
#
# Untagged: Berbicara di sela KTT ASEAN , Dung mengemukakan kepada Reuters , negara -nya , yang pada Kamis , resmi menjadi anggota Organisasi Perdagangan Dunia ( WTO ) , akan memperkuat transparansi untuk menarik investasi asing .
#
# HMM-tagged: Berbicara/VB di/IN sela/NN KTT/NNP ASEAN/NNP ,/Z Dung/SC mengemukakan/VB kepada/IN Reuters/NNP ,/Z negara/NN -nya/PRP ,/Z yang/SC pada/IN Kamis/NNP ,/Z resmi/JJ menjadi/VB anggota/NN Organisasi/NNP Perdagangan/NNP Dunia/NNP (/Z WTO/NNP )/Z ,/Z akan/MD memperkuat/VB transparansi/NN untuk/SC menarik/VB investasi/NN asing/JJ ./Z
#
# Entropy: 14.460081819784897
#
# ------------------------------------------------------------
# Test: Itu/PR lah/RP rencana/NN kami/PRP untuk/IN 2007/CD dan/CC 2008/CD ,/Z menswastakan/VB 104/CD badan/NN usaha/NN milik/NN negara/NN termasuk/VB Vietnam/NNP Airlines/NNP serta/CC industri/NN minyak/NN dan/CC gas/NN ./Z
#
# Untagged: Itu lah rencana kami untuk 2007 dan 2008 , menswastakan 104 badan usaha milik negara termasuk Vietnam Airlines serta industri minyak dan gas .
#
# HMM-tagged: Itu/PR lah/RP rencana/NN kami/PRP untuk/IN 2007/CD dan/CC 2008/CD ,/Z menswastakan/SYM 104/CD badan/NN usaha/NN milik/NN negara/NN termasuk/VB Vietnam/NNP Airlines/NNP serta/CC industri/NN minyak/NN dan/CC gas/NN ./Z
#
# Entropy: 9.794737599669338
#
# ------------------------------------------------------------
# Test: Kami/PRP juga/RB akan/MD memperkuat/VB keterbukaan/NN dan/CC transparansi/NN sebagaimana/SC negara/NN lain/JJ -nya/PRP sesama/NN anggota/NN WTO/NNP serta/CC sebagaimana/SC diatur/VB WTO/NNP ./Z
#
# Untagged: Kami juga akan memperkuat keterbukaan dan transparansi sebagaimana negara lain -nya sesama anggota WTO serta sebagaimana diatur WTO .
#
# HMM-tagged: Kami/PRP juga/RB akan/MD memperkuat/VB keterbukaan/NN dan/CC transparansi/NN sebagaimana/SC negara/NN lain/JJ -nya/PRP sesama/NN anggota/NN WTO/NNP serta/CC sebagaimana/SC diatur/VB WTO/NNP ./Z
#
# Entropy: 9.685921817500587
#
# ------------------------------------------------------------
# Test: Serangan/NN udara/NN terhadap/IN pejuang/NN buron/NN di/IN Somalia/NNP selatan/NN beberapa/CD hari/NN terakhir/OD secara/IN salah/JJ mengarah/VB gembala/NN pengembara/NN di/IN sekeliling/NN api unggun/NN ,/Z menewaskan/VB 70/CD orang/NN ,/Z kata/VB badan/NN bantuan/NN berpusat/VB di/IN Inggris/NNP ,/Z Oxfam/NNP ,/Z Jumat/NNP ./Z
#
# Untagged: Serangan udara terhadap pejuang buron di Somalia selatan beberapa hari terakhir secara salah mengarah gembala pengembara di sekeliling api unggun , menewaskan 70 orang , kata badan bantuan berpusat di Inggris , Oxfam , Jumat .
#
# HMM-tagged: Serangan/NN udara/NN terhadap/IN pejuang/NN buron/JJ di/IN Somalia/NNP selatan/NNP beberapa/CD hari/NN terakhir/JJ secara/IN salah/JJ mengarah/VB gembala/SYM pengembara/CD di/IN sekeliling/NN api unggun/PR ,/Z menewaskan/VB 70/CD orang/NN ,/Z kata/VB badan/NN bantuan/NN berpusat/VB di/IN Inggris/NNP ,/Z Oxfam/NNP ,/Z Jumat/NNP ./Z
#
# Entropy: 29.047252673826648
#
# ------------------------------------------------------------
# Test: Di/IN bawah/NN undang-undang/NN antarbangsa/JJ ,/Z ada/VB kewajiban/NN membedakan/VB sasaran/NN tentara/NN dan/CC penduduk/NN ,/Z tambah/VB Oxfam/NNP ,/Z dengan/SC mengutip/VB keterangan/NN kelompok/NN mitra/NN setempat/NN -nya/PRP di/IN Somalia/NNP ./Z
#
# Untagged: Di bawah undang-undang antarbangsa , ada kewajiban membedakan sasaran tentara dan penduduk , tambah Oxfam , dengan mengutip keterangan kelompok mitra setempat -nya di Somalia .
#
# HMM-tagged: Di/IN bawah/NN undang-undang/NN antarbangsa/PR ,/Z ada/VB kewajiban/NN membedakan/VB sasaran/NN tentara/NN dan/CC penduduk/NN ,/Z tambah/VB Oxfam/PRP ,/Z dengan/SC mengutip/VB keterangan/NN kelompok/NN mitra/NN setempat/NN -nya/PRP di/IN Somalia/NNP ./Z
#
# Entropy: 13.477389411195865
#
# ------------------------------------------------------------
# Test: Washington/NNP hari/NN Senin/NNP mengirim/VB pesawat tempur/NN ke/IN Somalia/NNP untuk/SC mencoba/VB dan/CC mengambil/VB yang/SC disebut/VB pejabat/NN Amerika/NNP Serikat/NNP tersangka/NN tertinggi/JJ Alqaida/NNP ,/Z yang/SC bersembunyi/VB dengan/SC pejuang/NN ./Z
#
# Untagged: Washington hari Senin mengirim pesawat tempur ke Somalia untuk mencoba dan mengambil yang disebut pejabat Amerika Serikat tersangka tertinggi Alqaida , yang bersembunyi dengan pejuang .
#
# HMM-tagged: Washington/NNP hari/NN Senin/NNP mengirim/VB pesawat tempur/PRP ke/IN Somalia/NNP untuk/SC mencoba/VB dan/CC mengambil/VB yang/SC disebut/VB pejabat/NN Amerika/NNP Serikat/NNP tersangka/NN tertinggi/JJ Alqaida/PRP ,/Z yang/SC bersembunyi/VB dengan/IN pejuang/NN ./Z
#
# Entropy: 17.218325349636963
#
# ------------------------------------------------------------
# Test: Etiopia/NNP ,/Z yang/SC menolong/VB pemerintah/NN sementara/SC Somalia/NNP mengusir/VB pejuang/NN pesaing/NN -nya/PRP dari/IN Mogadishu/NNP pada/IN Tahun/NN Baru/NN ,/Z juga/RB melancarkan/VB serangan/NN udara/NN terhadap/IN pejuang/NN ,/Z yang/SC mundur/VB ./Z
#
# Untagged: Etiopia , yang menolong pemerintah sementara Somalia mengusir pejuang pesaing -nya dari Mogadishu pada Tahun Baru , juga melancarkan serangan udara terhadap pejuang , yang mundur .
#
# HMM-tagged: Etiopia/PRP ,/Z yang/SC menolong/VB pemerintah/NN sementara/SC Somalia/NNP mengusir/VB pejuang/NN pesaing/NN -nya/PRP dari/IN Mogadishu/NNP pada/IN Tahun/NN Baru/NNP ,/Z juga/RB melancarkan/VB serangan/NN udara/NN terhadap/IN pejuang/NN ,/Z yang/SC mundur/VB ./Z
#
# Entropy: 11.969798771404726
#
# ------------------------------------------------------------
# Test: Sementara/SC itu/PR ,/Z beberapa/CD sumber/NN Somalia/NNP melaporkan/VB sejumlah/CD kematian/NN ,/Z tidak/NEG ada/VB penegasan/NN mandiri/JJ tentang/IN masalah/NN tersebut/PR ./Z
#
# Untagged: Sementara itu , beberapa sumber Somalia melaporkan sejumlah kematian , tidak ada penegasan mandiri tentang masalah tersebut .
#
# HMM-tagged: Sementara/SC itu/PR ,/Z beberapa/CD sumber/NN Somalia/NNP melaporkan/VB sejumlah/CD kematian/NN ,/Z tidak/NEG ada/VB penegasan/NN mandiri/JJ tentang/IN masalah/NN tersebut/PR ./Z
#
# Entropy: 6.425042416386486
#
# ------------------------------------------------------------
# Test: Oxfam/NNP menerima/VB laporan/NN dari/IN kelompok/NN mitra/NN -nya/PRP di/IN Somalia/NNP bahwa/SC gembala/NN pengembara/NN secara/IN salah/JJ disasar/VB dalam/IN pengeboman/NN baru-baru ini/RB ,/Z kata/VB Oxfam/NNP dalam/IN pernyataan/NN -nya/PRP ,/Z yang/SC dilansir/VB in/FW Nairobi/NNP ./Z
#
# Untagged: Oxfam menerima laporan dari kelompok mitra -nya di Somalia bahwa gembala pengembara secara salah disasar dalam pengeboman baru-baru ini , kata Oxfam dalam pernyataan -nya , yang dilansir in Nairobi .
#
# HMM-tagged: Oxfam/SC menerima/VB laporan/NN dari/IN kelompok/NN mitra/NN -nya/PRP di/IN Somalia/NNP bahwa/SC gembala/MD pengembara/VB secara/IN salah/JJ disasar/PRP dalam/IN pengeboman/NN baru-baru ini/RB ,/Z kata/VB Oxfam/PRP dalam/IN pernyataan/NN -nya/PRP ,/Z yang/SC dilansir/VB in/NNP Nairobi/NNP ./Z
#
# Entropy: 27.294761980734997
#
# ------------------------------------------------------------
# Test: Menurut/IN laporan/NN kelompok/NN setempat/NN di/IN kabupaten/NN Afmadow/NNP di/IN dekat/JJ perbatasan/NN Kenya/NNP ,/Z bom/NN menghantam/VB sumber/NN air/NN penting/JJ dan/CC kelompok/NN besar/JJ pengembara/NN dan/CC gembalaan/NN -nya/PRP ,/Z yang/SC berkerumun/VB di/IN sekeliling/NN api unggun/NN besar/JJ pada/IN malam/NN hari/NN untuk/SC menangkal/VB nyamuk/NN ,/Z kata/VB -nya/PRP ./Z
#
# Untagged: Menurut laporan kelompok setempat di kabupaten Afmadow di dekat perbatasan Kenya , bom menghantam sumber air penting dan kelompok besar pengembara dan gembalaan -nya , yang berkerumun di sekeliling api unggun besar pada malam hari untuk menangkal nyamuk , kata -nya .
#
# HMM-tagged: Menurut/IN laporan/NN kelompok/NN setempat/NN di/IN kabupaten/NN Afmadow/NNP di/IN dekat/JJ perbatasan/NN Kenya/NNP ,/Z bom/NN menghantam/VB sumber/NN air/NN penting/JJ dan/CC kelompok/NN besar/JJ pengembara/Z dan/CC gembalaan/VB -nya/PRP ,/Z yang/SC berkerumun/VB di/IN sekeliling/NN api unggun/RB besar/JJ pada/IN malam/NN hari/NN untuk/SC menangkal/VB nyamuk/NN ,/Z kata/VB -nya/PRP ./Z
#
# Entropy: 28.4092362502376
#
# ------------------------------------------------------------
# Test: Laporan/NN lebih/RB lanjut/VB juga/RB menegaskan/VB bahwa/SC pengeboman/NN merenggut/VB nyawa/NN 70/CD orang/NN di/IN kabupaten/NN itu/PR ,/Z kata/VB -nya/PRP ,/Z dengan/SC menambahkan/VB bahwa/SC perkara/NN itu/PR harus/MD ditangani/VB sungguh-sungguh/RB ./Z
#
# Untagged: Laporan lebih lanjut juga menegaskan bahwa pengeboman merenggut nyawa 70 orang di kabupaten itu , kata -nya , dengan menambahkan bahwa perkara itu harus ditangani sungguh-sungguh .
#
# HMM-tagged: Laporan/NN lebih/RB lanjut/VB juga/RB menegaskan/VB bahwa/SC pengeboman/NN merenggut/VB nyawa/SYM 70/CD orang/NN di/IN kabupaten/NN itu/PR ,/Z kata/VB -nya/PRP ,/Z dengan/SC menambahkan/VB bahwa/SC perkara/NN itu/PR harus/MD ditangani/VB sungguh-sungguh/RB ./Z
#
# Entropy: 15.94556364144711
#
# ------------------------------------------------------------
# Test: Sejak/IN perang terbuka/NN dimulai/VB akhir/NN Desember/NNP ,/Z sekitar/IN 70,000/CD orang/NN Somalia/NNP melarikan diri/VB ,/Z semakin/RB memperburuk/VB keadaan/NN kemanusiaan/NN ,/Z kata/VB Oxfam/NNP ./Z
#
# Untagged: Sejak perang terbuka dimulai akhir Desember , sekitar 70,000 orang Somalia melarikan diri , semakin memperburuk keadaan kemanusiaan , kata Oxfam .
#
# HMM-tagged: Sejak/IN perang terbuka/NN dimulai/VB akhir/NN Desember/NNP ,/Z sekitar/IN 70,000/NN orang/NN Somalia/NNP melarikan diri/VB ,/Z semakin/RB memperburuk/VB keadaan/NN kemanusiaan/NN ,/Z kata/VB Oxfam/PRP ./Z
#
# Entropy: 19.454497928566187
#
# ------------------------------------------------------------
# Test: Seorang/NND polisi/NN lalu lintas/NN India/NNP dialihtugaskan/VB gara-gara/SC tidak/NEG tahu/VB bahwa/SC pesohor/NN kadang/RB kebal/JJ hukum/NN ,/Z dengan/SC memberi/VB surat/NN bukti/NN pelanggaran/NN (/Z Tilang/NN )/Z kepada/IN seorang/NND bintang/NN terbesar/JJ olahraga/NN kriket/X ./Z
#
# Untagged: Seorang polisi lalu lintas India dialihtugaskan gara-gara tidak tahu bahwa pesohor kadang kebal hukum , dengan memberi surat bukti pelanggaran ( Tilang ) kepada seorang bintang terbesar olahraga kriket .
#
# HMM-tagged: Seorang/NND polisi/NN lalu lintas/NN India/NNP dialihtugaskan/Z gara-gara/CC tidak/NEG tahu/VB bahwa/SC pesohor/MD kadang/RB kebal/JJ hukum/NN ,/Z dengan/SC memberi/VB surat/NN bukti/NN pelanggaran/NN (/Z Tilang/NNP )/Z kepada/IN seorang/NND bintang/NN terbesar/JJ olahraga/NN kriket/PR ./Z
#
# Entropy: 30.134950550852192
#
# ------------------------------------------------------------
# Test: Media/NN di/IN India/NNP hari/NN Jumat/NNP melaporkan/VB Inspektur/NNP Saifuddin/NNP Ahmed/NNP di/IN kota/NNP Ranchi/NNP mengira/VB mengerjakan/VB kewajiban/NN -nya/PRP dengan/SC memberhentikan/VB kendaraan/NN sport/FW mewah/JJ ,/Z yang/SC dipasangi/VB kaca/NN film/NN gelap/JJ ,/Z yang/SC di/IN India/NNP merupakan/VB perlengkapan/NN terlarang/VB ./Z
#
# Untagged: Media di India hari Jumat melaporkan Inspektur Saifuddin Ahmed di kota Ranchi mengira mengerjakan kewajiban -nya dengan memberhentikan kendaraan sport mewah , yang dipasangi kaca film gelap , yang di India merupakan perlengkapan terlarang .
#
# HMM-tagged: Media/NNP di/IN India/NNP hari/NN Jumat/NNP melaporkan/VB Inspektur/IN Saifuddin/NNP Ahmed/NNP di/IN kota/NN Ranchi/PR mengira/MD mengerjakan/VB kewajiban/NN -nya/PRP dengan/SC memberhentikan/VB kendaraan/NN sport/FW mewah/FW ,/Z yang/SC dipasangi/VB kaca/NN film/NN gelap/JJ ,/Z yang/SC di/IN India/NNP merupakan/VB perlengkapan/NN terlarang/VB ./Z
#
# Entropy: 40.70715800685792
#
# ------------------------------------------------------------
# Test: Kendaraan/NN itu/PR berisi/VB pesohor/NN paling/RB tenar/JJ di/IN India/NNP ,/Z yaitu/SC pemain/NN kriket/X Mahendra/NNP Singh/NNP Dhoni/NNP ,/Z yang/SC dianggap/VB sebagai/IN pahlawan/NN di/IN daerah/NN asal/NN -nya/PRP ,/Z yaitu/SC negara bagian/NNP Jharkhand/NNP ,/Z Ranchi/NNP adalah/VB ibu kota/NN negara bagian/NN itu/PR ./Z
#
# Untagged: Kendaraan itu berisi pesohor paling tenar di India , yaitu pemain kriket Mahendra Singh Dhoni , yang dianggap sebagai pahlawan di daerah asal -nya , yaitu negara bagian Jharkhand , Ranchi adalah ibu kota negara bagian itu .
#
# HMM-tagged: Kendaraan/NN itu/PR berisi/VB pesohor/NN paling/RB tenar/JJ di/IN India/NNP ,/Z yaitu/SC pemain/NN kriket/X Mahendra/NNP Singh/NNP Dhoni/NNP ,/Z yang/SC dianggap/VB sebagai/IN pahlawan/NN di/IN daerah/NN asal/NN -nya/PRP ,/Z yaitu/SC negara bagian/NN Jharkhand/PR ,/Z Ranchi/SC adalah/VB ibu kota/NN negara bagian/NN itu/PR ./Z
#
# Entropy: 29.334774336317714
#
# ------------------------------------------------------------
# Test: Laporan/NN awal/NN mengatakan/VB ,/Z Ahmad/NNP tidak/NEG sungkan/JJ menagih/VB denda/NN 900/CD rupee/NN (/Z sekitar/IN Rp/SYM 180/CD ribu/CD )/Z kepada/IN Dhoni/NNP ./Z
#
# Untagged: Laporan awal mengatakan , Ahmad tidak sungkan menagih denda 900 rupee ( sekitar Rp 180 ribu ) kepada Dhoni .
#
# HMM-tagged: Laporan/NN awal/NN mengatakan/VB ,/Z Ahmad/NNP tidak/NEG sungkan/MD menagih/VB denda/NN 900/CD rupee/CD (/Z sekitar/IN Rp/SYM 180/CD ribu/CD )/Z kepada/IN Dhoni/NNP ./Z
#
# Entropy: 20.014476976221097
#
# ------------------------------------------------------------
# Test: Tapi/CC kemudian/CC ,/Z polisi/NN mengubah/VB keterangan/NN dengan/SC mengatakan/VB Dhoni/NNP dibolehkan/VB meneruskan/VB perjalanan/NN setelah/SC menunjukkan/VB surat/NN dari/IN pemerintah/NN setempat/NN ,/Z yang/SC memberi/VB kelonggaran/NN khusus/JJ kepada/IN -nya/PRP saat/NN melanggar/VB hukum/NN ./Z
#
# Untagged: Tapi kemudian , polisi mengubah keterangan dengan mengatakan Dhoni dibolehkan meneruskan perjalanan setelah menunjukkan surat dari pemerintah setempat , yang memberi kelonggaran khusus kepada -nya saat melanggar hukum .
#
# HMM-tagged: Tapi/CC kemudian/NN ,/Z polisi/NN mengubah/VB keterangan/NN dengan/SC mengatakan/VB Dhoni/PRP dibolehkan/MD meneruskan/VB perjalanan/NN setelah/SC menunjukkan/VB surat/NN dari/IN pemerintah/NN setempat/NN ,/Z yang/SC memberi/VB kelonggaran/NN khusus/JJ kepada/IN -nya/PRP saat/NN melanggar/VB hukum/NN ./Z
#
# Entropy: 17.655266129111368
#
# ------------------------------------------------------------
# Test: Ahmad/NNP dialihtugaskan/VB dan/CC tampak/VB merupakan/VB penurunan/NN jabatan/NN ,/Z dari/IN daerah/NN niaga/NN di/IN pusat/NN kota/NN ke/IN pasar/NN di/IN permukiman/NN ,/Z kata/VB Hindustan/NNP Times/NNP hari/NN Jumat/NNP ./Z
#
# Untagged: Ahmad dialihtugaskan dan tampak merupakan penurunan jabatan , dari daerah niaga di pusat kota ke pasar di permukiman , kata Hindustan Times hari Jumat .
#
# HMM-tagged: Ahmad/NNP dialihtugaskan/Z dan/CC tampak/VB merupakan/VB penurunan/NN jabatan/NN ,/Z dari/IN daerah/NN niaga/NN di/IN pusat/NN kota/NN ke/IN pasar/NN di/IN permukiman/NN ,/Z kata/VB Hindustan/IN Times/NNP hari/NN Jumat/NNP ./Z
#
# Entropy: 19.5278994797318
#
# ------------------------------------------------------------
# Test: Menteri/NN utama/JJ negara bagian/NN tersebut/PR dilaporkan/VB berkata/VB bahwa/SC pesohor/NN seharusnya/RB mendapatkan/VB perlakuan/NN khusus/JJ saat/NN berhadapan/VB dengan/IN hukum/NN ./Z
#
# Untagged: Menteri utama negara bagian tersebut dilaporkan berkata bahwa pesohor seharusnya mendapatkan perlakuan khusus saat berhadapan dengan hukum .
#
# HMM-tagged: Menteri/NN utama/JJ negara bagian/NN tersebut/PR dilaporkan/VB berkata/VB bahwa/SC pesohor/MD seharusnya/RB mendapatkan/VB perlakuan/NN khusus/JJ saat/NN berhadapan/VB dengan/IN hukum/NN ./Z
#
# Entropy: 14.208599446681292
#
# ------------------------------------------------------------
# Test: Polisi/NN itu/PR seharusnya/RB tidak/NEG bersikap/VB picik/JJ ketika/SC berhadapan/VB dengan/IN orang/NN berkedudukan/VB lebih/RB tinggi/JJ ,/Z kata/VB Madhu/NNP Koda/NNP ./Z
#
# Untagged: Polisi itu seharusnya tidak bersikap picik ketika berhadapan dengan orang berkedudukan lebih tinggi , kata Madhu Koda .
#
# HMM-tagged: Polisi/NN itu/PR seharusnya/RB tidak/NEG bersikap/VB picik/NN ketika/SC berhadapan/VB dengan/IN orang/NN berkedudukan/VB lebih/RB tinggi/JJ ,/Z kata/VB Madhu/SYM Koda/CD ./Z
#
# Entropy: 15.522036070335943
#
# ------------------------------------------------------------
# Test: Apa/WH masalah/NN -nya/PRP jika/SC orang/NN dengan/IN kedudukan/NN seperti/IN itu/PR menggunakan/VB kendaraan/NN dengan/IN kaca/NN film/NN ,/Z yang/SC gelap/JJ kata/VB -nya/PRP ./Z
#
# Untagged: Apa masalah -nya jika orang dengan kedudukan seperti itu menggunakan kendaraan dengan kaca film , yang gelap kata -nya .
#
# HMM-tagged: Apa/WH masalah/NN -nya/PRP jika/SC orang/NN dengan/SC kedudukan/VB seperti/IN itu/PR menggunakan/VB kendaraan/NN dengan/IN kaca/NN film/NN ,/Z yang/SC gelap/MD kata/VB -nya/PRP ./Z
#
# Entropy: 13.193638454195728
#
# ------------------------------------------------------------
# Test: Seorang/NND penyerang/NN jibaku/VB menabrakkan/VB kombi/X mini/JJ penuh/JJ bom/NN ke/IN kendaraan/NN membawa/VB orang asing/NN di/IN selatan/NN Kabul/NNP hari/NN Jumat/NNP ,/Z melukai/VB seorang/NND warga/NN Amerika/NNP Serikat/NNP dan/CC dua/CD penduduk/NN Afgan/NNP ,/Z kata/VB polisi/NN ./Z
#
# Untagged: Seorang penyerang jibaku menabrakkan kombi mini penuh bom ke kendaraan membawa orang asing di selatan Kabul hari Jumat , melukai seorang warga Amerika Serikat dan dua penduduk Afgan , kata polisi .
#
# HMM-tagged: Seorang/NND penyerang/NN jibaku/FW menabrakkan/FW kombi/FW mini/FW penuh/JJ bom/NN ke/IN kendaraan/NN membawa/VB orang asing/NN di/IN selatan/NN Kabul/IN hari/NN Jumat/NNP ,/Z melukai/VB seorang/NND warga/NN Amerika/NNP Serikat/NNP dan/CC dua/CD penduduk/NN Afgan/NNP ,/Z kata/VB polisi/NN ./Z
#
# Entropy: 27.83645607235902
#
# ------------------------------------------------------------
# Test: Ledakan/NN itu/PR terjadi/VB di/IN provinsi/NNP Logar/NNP ,/Z sekitar/IN 50/CD kilometer/NND dari/IN ibu kota/NN Afganistan/NNP ,/Z kata kepala/NN penyelidikan/NN kejahatan/NN kota/NN tersebut/PR ,/Z Ali/NNP Shah/NNP Paktiawal/NNP ,/Z kepada/IN kantor berita/NNP Prancis/NNP AFP/NNP dari/IN tempat/NN kejadian/NN itu/PR ./Z
#
# Untagged: Ledakan itu terjadi di provinsi Logar , sekitar 50 kilometer dari ibu kota Afganistan , kata kepala penyelidikan kejahatan kota tersebut , Ali Shah Paktiawal , kepada kantor berita Prancis AFP dari tempat kejadian itu .
#
# HMM-tagged: Ledakan/NN itu/PR terjadi/VB di/IN provinsi/NN Logar/PR ,/Z sekitar/IN 50/CD kilometer/NND dari/IN ibu kota/NN Afganistan/NNP ,/Z kata kepala/NN penyelidikan/NN kejahatan/NN kota/NN tersebut/PR ,/Z Ali/NNP Shah/NNP Paktiawal/NNP ,/Z kepada/IN kantor berita/NNP Prancis/NNP AFP/NNP dari/IN tempat/NN kejadian/NN itu/PR ./Z
#
# Entropy: 16.989989564521267
#
# ------------------------------------------------------------
# Test: Paktiawal/NNP menyatakan/VB kendaraan/NN sasaran/NN itu/PR bukan/NEG mobil/NN tentara/NN dan/CC orang/NN Amerika/NNP Serikat/NNP terluka/VB itu/PR bukan/NEG tentara/NN ./Z
#
# Untagged: Paktiawal menyatakan kendaraan sasaran itu bukan mobil tentara dan orang Amerika Serikat terluka itu bukan tentara .
#
# HMM-tagged: Paktiawal/SC menyatakan/VB kendaraan/NN sasaran/NN itu/PR bukan/NEG mobil/NN tentara/NN dan/CC orang/NN Amerika/NNP Serikat/NNP terluka/VB itu/PR bukan/NEG tentara/NN ./Z
#
# Entropy: 7.802425096972471
#
# ------------------------------------------------------------
# Test: Pasukan/NNP Bantuan/NNP Keamanan/NNP Antarbangsa/NNP (/Z ISAF/NNP )/Z pimpinan/NN persekutuan/NN pertahanan/NN Atlantik/NNP utara/NN NATO/NNP menyatakan/VB mobil/NN itu/PR milik/NN kontraktor/NN sipil/JJ Amerika/NNP Serikat/NNP ./Z
#
# Untagged: Pasukan Bantuan Keamanan Antarbangsa ( ISAF ) pimpinan persekutuan pertahanan Atlantik utara NATO menyatakan mobil itu milik kontraktor sipil Amerika Serikat .
#
# HMM-tagged: Pasukan/NN Bantuan/NN Keamanan/NNP Antarbangsa/NNP (/Z ISAF/NNP )/Z pimpinan/NN persekutuan/NNP pertahanan/NNP Atlantik/NNP utara/NNP NATO/NNP menyatakan/VB mobil/NN itu/PR milik/NN kontraktor/NN sipil/JJ Amerika/NNP Serikat/NNP ./Z
#
# Entropy: 14.965303867327398
#
# ------------------------------------------------------------
# Test: ISAF/NNP menyatakan/VB ledakan/NN tersebut/PR bukan/NEG serangan/NN jibaku/VB ,/Z tapi/CC juru potret/NN AFP/NNP di/IN tempat/NN kejadian/NN itu/PR melihat/VB jasad/NN laki-laki/NN ,/Z yang/SC disebut/VB polisi/NN penyerang/NN jibaku/VB -nya/PRP ./Z
#
# Untagged: ISAF menyatakan ledakan tersebut bukan serangan jibaku , tapi juru potret AFP di tempat kejadian itu melihat jasad laki-laki , yang disebut polisi penyerang jibaku -nya .
#
# HMM-tagged: ISAF/NNP menyatakan/VB ledakan/NN tersebut/PR bukan/NEG serangan/NN jibaku/PR ,/Z tapi/CC juru potret/NNP AFP/NNP di/IN tempat/NN kejadian/NN itu/PR melihat/VB jasad/NN laki-laki/NN ,/Z yang/SC disebut/VB polisi/NN penyerang/NN jibaku/JJ -nya/PRP ./Z
#
# Entropy: 20.191493246146955
#
# ------------------------------------------------------------
# Test: Mobil/NN sasaran/NN -nya/PRP terbakar/VB ,/Z kata/VB juru potret/NN tersebut/PR ./Z
#
# Untagged: Mobil sasaran -nya terbakar , kata juru potret tersebut .
#
# HMM-tagged: Mobil/NN sasaran/NN -nya/PRP terbakar/VB ,/Z kata/VB juru potret/NN tersebut/PR ./Z
#
# Entropy: 6.764741247741472
#
# ------------------------------------------------------------
# Test: Pejuang/NNP Talib/NNP melancarkan/VB pemberontakan/NN melawan/VB pemerintah/NN dukungan/NN Amerika/NNP Serikat/NNP dan/CC melakukan/VB pengeboman/NN jibaku/VB di/IN Afganistan/NNP tahun/NN lalu/CC sebagai/IN bagian/NN dari/IN peningkatan/NN gerakan/NN gerilya/NN maut/NN -nya/PRP ./Z
#
# Untagged: Pejuang Talib melancarkan pemberontakan melawan pemerintah dukungan Amerika Serikat dan melakukan pengeboman jibaku di Afganistan tahun lalu sebagai bagian dari peningkatan gerakan gerilya maut -nya .
#
# HMM-tagged: Pejuang/NN Talib/SC melancarkan/VB pemberontakan/NN melawan/VB pemerintah/NN dukungan/NN Amerika/NNP Serikat/NNP dan/CC melakukan/VB pengeboman/NN jibaku/JJ di/IN Afganistan/NNP tahun/NN lalu/CC sebagai/IN bagian/NN dari/IN peningkatan/NN gerakan/NN gerilya/NN maut/NN -nya/PRP ./Z
#
# Entropy: 22.104124020699714
#
# ------------------------------------------------------------
# Test: ISAF/NNP menyatakan/VB terjadi/VB sekitar/IN 117/CD pengeboman/NN jibaku/VB pada/IN 2006/CD ./Z
#
# Untagged: ISAF menyatakan terjadi sekitar 117 pengeboman jibaku pada 2006 .
#
# HMM-tagged: ISAF/NNP menyatakan/VB terjadi/VB sekitar/IN 117/CD pengeboman/NN jibaku/JJ pada/IN 2006/CD ./Z
#
# Entropy: 9.664370547535063
#
# ------------------------------------------------------------
# Test: Walaupun/SC kebanyakan/CD sasaran/NN -nya/PRP tentara/NN ,/Z mereka/PRP menewaskan/VB sekitar/IN 200/CD warga/NN dan/CC hampir/RB 70/CD tentara/NN Afgan/NNP dan/CC asing/JJ ,/Z kata/VB ISAF/NNP ./Z
#
# ...
#
# Untagged: Perdana Menteri Pakistan Shaukat Aziz juga memperingatkan negara Barat agar tidak menyerang Iran , sementara mantan presiden Iran Mohammad Khatami mendesak semua pihak agar meredakan ketegangan mengenai program nuklir Iran .
#
# HMM-tagged: Perdana/NNP Menteri/NNP Pakistan/NNP Shaukat/NNP Aziz/NNP juga/RB memperingatkan/VB negara Barat/NN agar/SC tidak/NEG menyerang/VB Iran/NNP ,/Z sementara/SC mantan/JJ presiden/NNP Iran/NNP Mohammad/NNP Khatami/MD mendesak/VB semua/CD pihak/NN agar/SC meredakan/VB ketegangan/PRP mengenai/IN program/NN nuklir/NN Iran/NNP ./Z
#
# Entropy: 20.329013325993913
#
# ------------------------------------------------------------
# Test: Jika/SC terjadi/VB aksi militer/NN ,/Z itu/PR akan/MD memiliki/VB akibat/NN berupa/VB bencana/NN ,/Z bukan/NEG hanya/RB di/IN wilayah/NN tersebut/PR ,/Z tapi/CC seluruh/CD dunia/NN ,/Z kata/VB Aziz/NNP ./Z
#
# Untagged: Jika terjadi aksi militer , itu akan memiliki akibat berupa bencana , bukan hanya di wilayah tersebut , tapi seluruh dunia , kata Aziz .
#
# HMM-tagged: Jika/SC terjadi/VB aksi militer/NN ,/Z itu/PR akan/MD memiliki/VB akibat/NN berupa/VB bencana/NN ,/Z bukan/NEG hanya/RB di/IN wilayah/NN tersebut/PR ,/Z tapi/CC seluruh/CD dunia/NN ,/Z kata/VB Aziz/NNP ./Z
#
# Entropy: 6.61935043706728
#
# ------------------------------------------------------------
# Test: Saya/PRP berharap/VB mereka/PRP cukup/RB baik/JJ dalam/IN menangani/VB keadaan/NN ./Z
#
# Untagged: Saya berharap mereka cukup baik dalam menangani keadaan .
#
# HMM-tagged: Saya/PRP berharap/VB mereka/PRP cukup/RB baik/JJ dalam/IN menangani/VB keadaan/NN ./Z
#
# Entropy: 2.89513575749849
#
# ------------------------------------------------------------
# Test: Kita/PRP perlu/MD sangat/RB bersabar/VB dan/CC memahami/VB dan/CC tidak/NEG terlalu/RB emosional/JJ ,/Z kata/VB Khatami/NNP ./Z
#
# Untagged: Kita perlu sangat bersabar dan memahami dan tidak terlalu emosional , kata Khatami .
#
# HMM-tagged: Kita/PRP perlu/MD sangat/RB bersabar/JJ dan/CC memahami/VB dan/CC tidak/NEG terlalu/RB emosional/JJ ,/Z kata/VB Khatami/PRP ./Z
#
# Entropy: 8.909184821154344
#
# ------------------------------------------------------------
# Test: ElBaradei/NNP mengatakan/VB kekerasan/NN tak/NEG bisa/MD dikesampingkan/VB ,/Z tapi/CC pengalaman/NN masa lalu/NN telah/MD memperlihatkan/VB itu/PR tak/NEG boleh/MD digunakan/VB secara/IN tergesa-gesa/JJ ,/Z ia/PRP merujuk/VB kepada/IN Irak/NNP ,/Z tempat/NN tak/NEG ada/VB bukti/NN yang/SC ditemukan/VB mengenai/IN senjata nuklir/NN setelah/SC serbuan/NN pimpinan/NN AS/NNP ./Z
#
# Untagged: ElBaradei mengatakan kekerasan tak bisa dikesampingkan , tapi pengalaman masa lalu telah memperlihatkan itu tak boleh digunakan secara tergesa-gesa , ia merujuk kepada Irak , tempat tak ada bukti yang ditemukan mengenai senjata nuklir setelah serbuan pimpinan AS .
#
# HMM-tagged: ElBaradei/SC mengatakan/VB kekerasan/NN tak/NEG bisa/MD dikesampingkan/VB ,/Z tapi/CC pengalaman/NN masa lalu/NN telah/MD memperlihatkan/VB itu/PR tak/NEG boleh/MD digunakan/VB secara/IN tergesa-gesa/NNP ,/Z ia/PRP merujuk/VB kepada/IN Irak/NNP ,/Z tempat/NN tak/NEG ada/VB bukti/NN yang/SC ditemukan/VB mengenai/IN senjata nuklir/NN setelah/SC serbuan/NN pimpinan/NN AS/NNP ./Z
#
# Entropy: 16.99910452940092
#
# ------------------------------------------------------------
# Test: Saya/PRP yakin/JJ satu-satunya/JJ cara/NN untuk/IN maju/VB di/IN Iran/NNP ialah/VB hubungan/NN ,/Z kata/VB ElBaradei/NNP ./Z Kita/PRP harus/MD menanam modal/VB pada/IN perdamaian/NN ,/Z kata/VB -nya/PRP ./Z
#
# Untagged: Saya yakin satu-satunya cara untuk maju di Iran ialah hubungan , kata ElBaradei . Kita harus menanam modal pada perdamaian , kata -nya .
#
# HMM-tagged: Saya/PRP yakin/JJ satu-satunya/JJ cara/NN untuk/SC maju/VB di/IN Iran/NNP ialah/VB hubungan/NN ,/Z kata/VB ElBaradei/PRP ./Z Kita/PRP harus/MD menanam modal/VB pada/IN perdamaian/NN ,/Z kata/VB -nya/PRP ./Z
#
# Entropy: 11.076765626534973
#
# ------------------------------------------------------------
# Test: Ditambahkan/VB -nya/PRP ,/Z kalau/SC masyarakat/NN internasional/JJ gagal/JJ melakukan/VB itu/PR ,/Z konsekuensi/NN -nya/PRP akan/MD 10/CD kali/NND lebih/RB buruk/JJ ./Z
#
# Untagged: Ditambahkan -nya , kalau masyarakat internasional gagal melakukan itu , konsekuensi -nya akan 10 kali lebih buruk .
#
# HMM-tagged: Ditambahkan/VB -nya/PRP ,/Z kalau/SC masyarakat/NN internasional/JJ gagal/JJ melakukan/VB itu/PR ,/Z konsekuensi/NN -nya/PRP akan/MD 10/CD kali/NN lebih/RB buruk/JJ ./Z
#
# Entropy: 7.120289900613189
#
# ------------------------------------------------------------
# Test: Saya/PRP harap/VB kita/PRP akan/MD berhenti/VB berbicara/VB mengenai/IN pilihan/NN militer/NN dan/CC memusatkan/VB perhatian/NN pada/IN pencarian/NN penyelesaian/NN ,/Z kata/VB ElBaradei/NNP ./Z
#
# Untagged: Saya harap kita akan berhenti berbicara mengenai pilihan militer dan memusatkan perhatian pada pencarian penyelesaian , kata ElBaradei .
#
# HMM-tagged: Saya/PRP harap/VB kita/PRP akan/MD berhenti/VB berbicara/VB mengenai/IN pilihan/NN militer/NN dan/CC memusatkan/NN perhatian/NN pada/IN pencarian/NN penyelesaian/NN ,/Z kata/VB ElBaradei/PRP ./Z
#
# Entropy: 11.526886292377853
#
# ------------------------------------------------------------
# Test: Iran/NNP menyatakan/VB negara/NN itu/PR memerlukan/VB tenaga nuklir/NN untuk/SC menghasilkan/VB listrik/NN ,/Z tapi/CC Barat/NNP khawatir/JJ Teheran/NNP secara/IN diam-diam/RB berusaha/VB membuat/VB bom atom/NN ./Z
#
# Untagged: Iran menyatakan negara itu memerlukan tenaga nuklir untuk menghasilkan listrik , tapi Barat khawatir Teheran secara diam-diam berusaha membuat bom atom .
#
# HMM-tagged: Iran/NNP menyatakan/VB negara/NN itu/PR memerlukan/VB tenaga nuklir/NN untuk/SC menghasilkan/VB listrik/NN ,/Z tapi/CC Barat/NNP khawatir/NNP Teheran/NNP secara/IN diam-diam/RB berusaha/VB membuat/VB bom atom/NN ./Z
#
# Entropy: 15.290422102171354
#
# ------------------------------------------------------------
# Test: Pada/IN Desember/NNP ,/Z PBB/NNP menjatuhkan/VB sanksi/NN atas/IN perdagangan/NN bahan/NN nuklir/NN peka/JJ kepada/IN Iran/NNP dan/CC teknologi/NN untuk/SC berusaha/VB dan/CC menghentikan/VB kegiatan/NN pengayaan/NN yang/SC dapat/MD menghasilkan/VB bahan/NN bom/NN ./Z
#
# Untagged: Pada Desember , PBB menjatuhkan sanksi atas perdagangan bahan nuklir peka kepada Iran dan teknologi untuk berusaha dan menghentikan kegiatan pengayaan yang dapat menghasilkan bahan bom .
#
# HMM-tagged: Pada/IN Desember/NNP ,/Z PBB/NNP menjatuhkan/VB sanksi/NN atas/IN perdagangan/NN bahan/NN nuklir/NN peka/JJ kepada/IN Iran/NNP dan/CC teknologi/NN untuk/SC berusaha/VB dan/CC menghentikan/VB kegiatan/NN pengayaan/NN yang/SC dapat/MD menghasilkan/VB bahan/NN bom/NN ./Z
#
# Entropy: 8.350916527304857
#
# ------------------------------------------------------------
# Test: Militer/NN Lebanon/NNP Kamis/NNP mengumumkan/VB diberlakukan/VB -nya/PRP jam malam/NN di/IN Beirut/NNP setelah/SC sedikitnya/RB empat/CD orang/NN tewas/VB dalam/IN bentrokan/NN antara/IN para/DT pegiat/NN pro/JJ dan/CC anti/JJ -/Z pemerintah/NN ./Z
#
# Untagged: Militer Lebanon Kamis mengumumkan diberlakukan -nya jam malam di Beirut setelah sedikitnya empat orang tewas dalam bentrokan antara para pegiat pro dan anti - pemerintah .
#
# HMM-tagged: Militer/NNP Lebanon/NNP Kamis/NNP mengumumkan/VB diberlakukan/VB -nya/PRP jam malam/NN di/IN Beirut/NNP setelah/SC sedikitnya/RB empat/CD orang/NN tewas/VB dalam/IN bentrokan/NN antara/IN para/DT pegiat/NN pro/JJ dan/CC anti/JJ -/Z pemerintah/NN ./Z
#
# Entropy: 11.034610776735748
#
# ------------------------------------------------------------
# Test: Jam/NN malam/NN akan/MD berlaku/VB efektif/JJ pada/IN pukul/NN 8/CD :/Z 30/CD sore/NN Kamis/NNP dan/CC akan/MD berakhir/VB sampai/IN pukul/NN 6/CD :/Z 0/CD pagi/NN waktu/NN setempat/NN Jumat/NNP ,/Z kata/VB seorang/NND juru bicara/NN militer/NN ./Z
#
# Untagged: Jam malam akan berlaku efektif pada pukul 8 : 30 sore Kamis dan akan berakhir sampai pukul 6 : 0 pagi waktu setempat Jumat , kata seorang juru bicara militer .
#
# HMM-tagged: Jam/IN malam/NN akan/MD berlaku/VB efektif/JJ pada/IN pukul/NN 8/CD :/Z 30/CD sore/NN Kamis/NNP dan/CC akan/MD berakhir/VB sampai/IN pukul/NN 6/CD :/Z 0/CD pagi/NN waktu/NN setempat/NN Jumat/NNP ,/Z kata/VB seorang/NND juru bicara/NN militer/NN ./Z
#
# Entropy: 12.406114006139177
#
# ------------------------------------------------------------
# Test: Dua/CD mahasiswa/NN oposisi/NN dan/CC dua/CD orang/NN lain/JJ -nya/PRP tewas/VB ditembak/VB dan/CC 100/CD orang/NN lain/JJ -nya/PRP cedera/JJ ,/Z kebanyakan/CD karena/SC serangan/NN senjata api/NN di/IN Universitas/NNP Arab/NNP Beirut/NNP ,/Z demikian/PR dilaporkan/VB Reuters/NNP ,/Z mengutip/VB sumber-sumber/NN keamanan/NN ./Z
#
# Untagged: Dua mahasiswa oposisi dan dua orang lain -nya tewas ditembak dan 100 orang lain -nya cedera , kebanyakan karena serangan senjata api di Universitas Arab Beirut , demikian dilaporkan Reuters , mengutip sumber-sumber keamanan .
#
# HMM-tagged: Dua/CD mahasiswa/NN oposisi/NN dan/CC dua/CD orang/NN lain/JJ -nya/PRP tewas/VB ditembak/VB dan/CC 100/CD orang/NN lain/JJ -nya/PRP cedera/JJ ,/Z kebanyakan/CD karena/SC serangan/NN senjata api/JJ di/IN Universitas/NNP Arab/NNP Beirut/NNP ,/Z demikian/PR dilaporkan/VB Reuters/NNP ,/Z mengutip/VB sumber-sumber/NN keamanan/NN ./Z
#
# Entropy: 15.776165226996746
#
# ------------------------------------------------------------
# Test: Pertempuran/NN meletus/VB antara/IN mahasiswa-mahasiswa/NN dengan/SC menggunakan/VB pentungan/NN dan/CC batu/NN di/IN kampus/NN universitas/NN tersebut/PR ,/Z kemudian/CC menyebar/VB ke/IN jalan-jalan/NN terdekat/JJ ,/Z demikian/PR laporan/NN tersebut/PR ./Z
#
# Untagged: Pertempuran meletus antara mahasiswa-mahasiswa dengan menggunakan pentungan dan batu di kampus universitas tersebut , kemudian menyebar ke jalan-jalan terdekat , demikian laporan tersebut .
#
# HMM-tagged: Pertempuran/NN meletus/VB antara/IN mahasiswa-mahasiswa/NN dengan/SC menggunakan/VB pentungan/NN dan/CC batu/NN di/IN kampus/NN universitas/NN tersebut/PR ,/Z kemudian/CC menyebar/VB ke/IN jalan-jalan/NN terdekat/JJ ,/Z demikian/PR laporan/NN tersebut/PR ./Z
#
# Entropy: 19.979893748259443
#
# ------------------------------------------------------------
# Test: Orang/NN bersenjata/VB membunuh/VB seorang/NND aktivis/NN yang/SC berhubungan/VB dengan/IN kelompok/NN militan/JJ Fatah/NNP Brigade/NNP Syahid/NNP Al/NNP Aqsa/NNP di/IN Gaza/NNP Jumat/NNP pagi/NN ,/Z kata/VB Fatah/NNP ,/Z beberapa/CD jam/NN setelah/SC seorang/NND anggota/NN pasukan/NN keamanan/NN pimpinan/NN Hamas/NNP juga/RB tewas/VB karena/SC ledakan/NN bom/NN pinggir/NN jalan/NN ./Z
#
# Untagged: Orang bersenjata membunuh seorang aktivis yang berhubungan dengan kelompok militan Fatah Brigade Syahid Al Aqsa di Gaza Jumat pagi , kata Fatah , beberapa jam setelah seorang anggota pasukan keamanan pimpinan Hamas juga tewas karena ledakan bom pinggir jalan .
#
# HMM-tagged: Orang/NN bersenjata/VB membunuh/VB seorang/NND aktivis/NN yang/SC berhubungan/VB dengan/IN kelompok/NN militan/JJ Fatah/NNP Brigade/NNP Syahid/NNP Al/NNP Aqsa/NNP di/IN Gaza/NNP Jumat/NNP pagi/NN ,/Z kata/VB Fatah/NNP ,/Z beberapa/CD jam/NN setelah/SC seorang/NND anggota/NN pasukan/NN keamanan/NN pimpinan/NN Hamas/NNP juga/RB tewas/VB karena/SC ledakan/NN bom/NN pinggir/NN jalan/NN ./Z
#
# Entropy: 22.825695757208376
#
# ------------------------------------------------------------
# Test: Lebih/RB dari/IN 30/CD warga/NN Palestina/NNP telah/MD terbunuh/VB dalam/IN perang/NN antara/IN kelompok-kelompok/NN Hamas/NNP dan/CC Fatah/NNP yang/SC berlawanan/VB ,/Z sejak/IN Presiden/NNP Palestina/NNP Mahmoud/NNP Abbas/NNP bulan/NN lalu/CC menyerukan/VB untuk/SC dilakukannya/NN pemilihan/NN presiden/NN dan/CC parlemen/NN lebih/RB awal/NN ./Z
#
# Untagged: Lebih dari 30 warga Palestina telah terbunuh dalam perang antara kelompok-kelompok Hamas dan Fatah yang berlawanan , sejak Presiden Palestina Mahmoud Abbas bulan lalu menyerukan untuk dilakukannya pemilihan presiden dan parlemen lebih awal .
#
# HMM-tagged: Lebih/RB dari/IN 30/CD warga/NN Palestina/NNP telah/MD terbunuh/VB dalam/IN perang/NN antara/IN kelompok-kelompok/NN Hamas/NNP dan/CC Fatah/NNP yang/SC berlawanan/VB ,/Z sejak/IN Presiden/NNP Palestina/NNP Mahmoud/NNP Abbas/NNP bulan/NN lalu/CC menyerukan/VB untuk/SC dilakukannya/VB pemilihan/NN presiden/NN dan/CC parlemen/NN lebih/RB awal/NN ./Z
#
# Entropy: 16.912479016785063
#
# ------------------------------------------------------------
# Test: Pejabat-pejabat/NN rumah sakit/NN mengkonfirmasikan/VB bahwa/SC aktivis/NN tersebut/PR tewas/VB dalam/IN serangan/NN di/IN Jalur/NNP Gaza/NNP utara/NNP ./Z
#
# Untagged: Pejabat-pejabat rumah sakit mengkonfirmasikan bahwa aktivis tersebut tewas dalam serangan di Jalur Gaza utara .
#
# HMM-tagged: Pejabat-pejabat/IN rumah sakit/NN mengkonfirmasikan/VB bahwa/SC aktivis/NN tersebut/PR tewas/VB dalam/IN serangan/NN di/IN Jalur/NNP Gaza/NNP utara/NNP ./Z
#
# Entropy: 8.883089677017509
#
# ------------------------------------------------------------
# Test: Fatah/NNP menuduh/VB pasukan/NN keamanan/NN pimpinan/NN Hamas/NNP yang/SC '/Z membunuh/VB '/Z aktivis/NN tersebut/PR ./Z
#
# Untagged: Fatah menuduh pasukan keamanan pimpinan Hamas yang ' membunuh ' aktivis tersebut .
#
# HMM-tagged: Fatah/NNP menuduh/VB pasukan/NN keamanan/NN pimpinan/NN Hamas/NNP yang/SC '/Z membunuh/VB '/Z aktivis/NN tersebut/PR ./Z
#
# Entropy: 6.799997663388092
#
# ------------------------------------------------------------
# Test: Seorang/NND juru bicara/NN bagi/IN pasukan/NN pimpinan/NN Hamas/NNP tak/NEG bisa/MD diperoleh/VB komentar/NN -nya/PRP mengenai/IN hal/NN itu/PR ./Z
#
# Untagged: Seorang juru bicara bagi pasukan pimpinan Hamas tak bisa diperoleh komentar -nya mengenai hal itu .
#
# HMM-tagged: Seorang/NND juru bicara/NN bagi/IN pasukan/NN pimpinan/NN Hamas/NNP tak/NEG bisa/MD diperoleh/VB komentar/NN -nya/PRP mengenai/IN hal/NN itu/PR ./Z
#
# Entropy: 4.5095831353614
#
# ------------------------------------------------------------
# Test: Para/DT penduduk/NN setempat/NN mengatakan/VB ,/Z para/DT anggota/NN pasukan/NN pimpinan/NN Hamas/NNP telah/MD mengepung/VB rumah/NN aktivis/NN tersebut/PR dan/CC kemudian/CC menyerang/VB -nya/PRP ./Z
#
# Untagged: Para penduduk setempat mengatakan , para anggota pasukan pimpinan Hamas telah mengepung rumah aktivis tersebut dan kemudian menyerang -nya .
#
# HMM-tagged: Para/DT penduduk/NN setempat/NN mengatakan/VB ,/Z para/DT anggota/NN pasukan/NN pimpinan/NN Hamas/NNP telah/MD mengepung/VB rumah/NN aktivis/NN tersebut/PR dan/CC kemudian/RB menyerang/VB -nya/PRP ./Z
#
# Entropy: 7.145662471934132
#
# ------------------------------------------------------------
# Test: Mereka/PRP mengajukan/VB pertanyaan/NN kepada/IN -nya/PRP berkaitan/VB dengan/SC peledakan/NN bom/NN pinggir/NN jalan/NN ./Z
#
# Untagged: Mereka mengajukan pertanyaan kepada -nya berkaitan dengan peledakan bom pinggir jalan .
#
# HMM-tagged: Mereka/PRP mengajukan/VB pertanyaan/NN kepada/IN -nya/PRP berkaitan/VB dengan/IN peledakan/NN bom/NN pinggir/NN jalan/NN ./Z
#
# Entropy: 7.313716802763086
#
# ------------------------------------------------------------
# Test: Ledakan/NN bom/NN meninggalkan/VB kedua/CD anggota/NN pasukan/NN pimpinan/NN Hamas/NNP itu/PR dalam/IN keadaan/NN kondisi/NN kritis/JJ dan/CC tujuh/CD lain/JJ -nya/PRP yang/SC menderita/VB luka-luka/NN ,/Z kata/VB para/DT pejabat/NN rumah sakit/NN ./Z
#
# Untagged: Ledakan bom meninggalkan kedua anggota pasukan pimpinan Hamas itu dalam keadaan kondisi kritis dan tujuh lain -nya yang menderita luka-luka , kata para pejabat rumah sakit .
#
# HMM-tagged: Ledakan/NN bom/NN meninggalkan/VB kedua/CD anggota/NN pasukan/NN pimpinan/NN Hamas/NNP itu/PR dalam/IN keadaan/NN kondisi/NN kritis/JJ dan/CC tujuh/CD lain/JJ -nya/PRP yang/SC menderita/VB luka-luka/NN ,/Z kata/VB para/DT pejabat/NN rumah sakit/NN ./Z
#
# Entropy: 10.270869927761881
#
# ------------------------------------------------------------
# accuracy over 50186 tokens: 91.55
# Testing Completed

# %%
# save model
filename = 'tagger_model.dill'
with open(filename, 'wb') as f:
    dill.dump(tagger, f)

# %%
# load model
with open(filename, 'rb') as f:
    hmm_tagger = dill.load(f)

# %%
# checking tag
def xcheck_tag(word,tag):
    punc = list(string.punctuation)
    punc.append('.')
    punc.append(',')
    punc.append('"')
    punc.append("'")
    
    dates = ['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember',\
            'Jan','Feb','Mar','Apr','Mei','Jun','Jul','Agt','Sep','Okt','Nov','Des',\
            'januari','februari','maret','april','mei','juni','juli','agustus','september','oktober','november','desember',\
            'Senin','Selasa','Rabu','Kamis','Jumat','Sabtu','Minggu'
        ]
    
    if(word in dates):
        tag = 'DATE'
    
    if(word in punc):
        tag = 'Z'
        
    if(tag == 'CD' and word.isdigit()):
        tag = 'CD'
        
    if(tag in ['SYM','Z','CD','MD'] and word.upper() != word and hasNumbers(word) == False \
      and word[-3:] not in ['nya','kah','lah']):
        tag = 'NNP'
    
    if(tag == 'NN' and word[:1].upper() == word):
        tag = 'NNP'
        
    if(tag == 'NNP' and word.lower() == word):
        tag = 'NN'
    
    if(tag == 'NNP' and len(word) == 1):
        tag = 'NN'
        
    if(tag == 'FW' and word.lower() == word):
        tag = 'NN'
        
    return word,tag

# %%
kalimat = "Andi selalu menjadi anak bawang di kelasnya."

word_punct_tokenizer = WordPunctTokenizer()
kalimat_token = word_punct_tokenizer.tokenize(kalimat)
kalimat_token
# Out:
# ['Andi', 'selalu', 'menjadi', 'anak', 'bawang', 'di', 'kelasnya', '.']

# %%
pos_tagging = hmm_tagger.tag(kalimat_token)
pos_tagging
# Out:
# [('Andi', 'NNP'),
#  ('selalu', 'RB'),
#  ('menjadi', 'VB'),
#  ('anak', 'NN'),
#  ('bawang', 'JJ'),
#  ('di', 'IN'),
#  ('kelasnya', 'NNP'),
#  ('.', 'Z')]

# %%
final_tagged = []
for pt in pos_tagging:
  w,t = xcheck_tag(pt[0], pt[1])
  final_tagged.append((w,t))

# %%
final_tagged
# Out:
# [('Andi', 'NNP'),
#  ('selalu', 'RB'),
#  ('menjadi', 'VB'),
#  ('anak', 'NN'),
#  ('bawang', 'JJ'),
#  ('di', 'IN'),
#  ('kelasnya', 'NN'),
#  ('.', 'Z')]

# %% [markdown]
# # CHUNKING

# %%
from nltk.tokenize import WordPunctTokenizer
from nltk import sent_tokenize
from nltk import word_tokenize, RegexpParser, ne_chunk
from collections import defaultdict
import string
import nltk

# %%
def chunk(kalimat):
    grammar = ["CHUNK: {<NN>{2,}}", "CHUNK: {<NN><CD>}", "CHUNK: {<CD><NN>}", "CHUNK: {<NNP><NN>}", "CHUNK: {<VB><NN>}",
               "CHUNK: {<VB><JJ>}", "CHUNK: {<VB><CD>}", "CHUNK: {<JJ><NN>}", "CHUNK: {<NN><JJ>}", "CHUNK: {<JJ><JJ>}"]
    
    result = []

    for i in grammar:
      chunkParser = RegexpParser(i)
      tree = chunkParser.parse(kalimat)
      for subtree in tree.subtrees():
          if(subtree.label()=="CHUNK"):
              tampung_entity = []
              for se in subtree.leaves():
                  tampung_entity.append(se[0])
              result.append(' '.join(tampung_entity))
    return result

# %%
def chunk(kalimat):
    grammar = ["CHUNK: {<NN>{2,}}", "CHUNK: {<NN><CD>}", "CHUNK: {<CD><NN>}", "CHUNK: {<NNP><NN>}", "CHUNK: {<VB><NN>}",
               "CHUNK: {<VB><JJ>}", "CHUNK: {<VB><CD>}", "CHUNK: {<JJ><NN>}", "CHUNK: {<NN><JJ>}", "CHUNK: {<JJ><JJ>}"]
    
    extract = []

    for i in grammar:
      cp = nltk.RegexpParser(i)
      result = cp.parse(kalimat)

      leaves = [chunk.leaves() for chunk in result if ((type(chunk) == nltk.tree.Tree) and chunk.label() == 'CHUNK')]
      noun_bigram_groups = [list(nltk.bigrams([w for w, t in leaf])) for leaf in leaves]

      ph = [' '.join(nouns) for group in noun_bigram_groups for nouns in group]
      extract = extract + ph

    return extract

# %%
ftag = [('Anak', 'NN'),
 ('kutu', 'NN'),
 ('buku', 'NN'),
 ('itu', 'PR'),
 ('menjuarai', 'VB'),
 ('lomba', 'NN'),
 ('matematika', 'PR'),
 ('.', 'Z')]

# %%
frasa = chunk(final_tagged)
frasa
# Out:
# ['menjadi anak', 'anak bawang']
